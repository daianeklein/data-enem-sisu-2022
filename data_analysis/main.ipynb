# %% [markdown]
# # ENEM & SISU

# %% [markdown]
# ## LIB'S

# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# ## DATA

# %%
path_enem_data = '/Users/daianeklein/Documents/DS/data-enem-sisu-2022/data/microdados_enem_2022/DADOS/MICRODADOS_ENEM_2022.csv'
enem_raw = pd.read_csv(path_enem_data, sep=';', encoding='latin-1')

enem_raw.shape

# %%
sisu_raw = pd.read_excel('../data/nota_corte_sisu_2023.xlsx',
                         'inscricao_2023_1')

sisu_raw.shape

# %%
sisu_df = sisu_raw.copy(deep=True)

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# ### SISU DATA

# %%
sisu_df.head()
# Out:
#    NU_ANO  NU_EDICAO  CO_IES                              NO_IES SG_IES  \
# 0    2023          1     580  UNIVERSIDADE FEDERAL DE PERNAMBUCO   UFPE
# 1    2023          1     580  UNIVERSIDADE FEDERAL DE PERNAMBUCO   UFPE
# 2    2023          1     580  UNIVERSIDADE FEDERAL DE PERNAMBUCO   UFPE
# 3    2023          1     580  UNIVERSIDADE FEDERAL DE PERNAMBUCO   UFPE
# 4    2023          1     580  UNIVERSIDADE FEDERAL DE PERNAMBUCO   UFPE
#
#   DS_ORGANIZACAO_ACADEMICA DS_CATEGORIA_ADM                  NO_CAMPUS  \
# 0             Universidade  Pública Federal  Campus do Agreste Caruaru
# 1             Universidade  Pública Federal  Campus do Agreste Caruaru
# 2             Universidade  Pública Federal  Campus do Agreste Caruaru
# 3             Universidade  Pública Federal  Campus do Agreste Caruaru
# 4             Universidade  Pública Federal  Campus do Agreste Caruaru
#
#   NO_MUNICIPIO_CAMPUS SG_UF_CAMPUS  ... CO_IES_CURSO  NO_CURSO       DS_GRAU  \
# 0             Caruaru           PE  ...       118098   QUÍMICA  Licenciatura
# 1             Caruaru           PE  ...       118098   QUÍMICA  Licenciatura
# 2             Caruaru           PE  ...       118098   QUÍMICA  Licenciatura
# 3             Caruaru           PE  ...       118098   QUÍMICA  Licenciatura
# 4             Caruaru           PE  ...       118098   QUÍMICA  Licenciatura
#
#   DS_TURNO TP_MOD_CONCORRENCIA  \
# 0  Noturno                   L
# 1  Noturno                   L
# 2  Noturno                   L
# 3  Noturno                   L
# 4  Noturno                   L
#
#                                  DS_MOD_CONCORRENCIA NU_PERCENTUAL_BONUS  \
# 0  Candidatos autodeclarados indígenas, com renda...                   0
# 1  Candidatos autodeclarados indígenas que, indep...                   0
# 2  Candidatos autodeclarados pretos ou pardos, co...                   0
# 3  Candidatos autodeclarados pretos ou pardos que...                   0
# 4  Candidatos com deficiência autodeclarados pret...                   0
#
#    QT_VAGAS_CONCORRENCIA  NU_NOTACORTE  QT_INSCRICAO
# 0                      1           NaN           NaN
# 1                      1           NaN           1.0
# 2                     11        564.04          52.0
# 3                     11        555.87          48.0
# 4                      1        441.18           2.0
#
# [5 rows x 21 columns]

# %%
sisu_df.columns
# Out:
# Index(['NU_ANO', 'NU_EDICAO', 'CO_IES', 'NO_IES', 'SG_IES',
#        'DS_ORGANIZACAO_ACADEMICA', 'DS_CATEGORIA_ADM', 'NO_CAMPUS',
#        'NO_MUNICIPIO_CAMPUS', 'SG_UF_CAMPUS', 'DS_REGIAO_CAMPUS',
#        'CO_IES_CURSO', 'NO_CURSO', 'DS_GRAU', 'DS_TURNO',
#        'TP_MOD_CONCORRENCIA', 'DS_MOD_CONCORRENCIA', 'NU_PERCENTUAL_BONUS',
#        'QT_VAGAS_CONCORRENCIA', 'NU_NOTACORTE', 'QT_INSCRICAO'],
#       dtype='object')

# %%
sisu_df.head(20).T
# Out:
#                                                                          0   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados indígenas, com renda...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                            NaN
# QT_INSCRICAO                                                            NaN
#
#                                                                          1   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados indígenas que, indep...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                            NaN
# QT_INSCRICAO                                                            1.0
#
#                                                                          2   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados pretos ou pardos, co...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                    11
# NU_NOTACORTE                                                         564.04
# QT_INSCRICAO                                                           52.0
#
#                                                                          3   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados pretos ou pardos que...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                    11
# NU_NOTACORTE                                                         555.87
# QT_INSCRICAO                                                           48.0
#
#                                                                          4   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência autodeclarados pret...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                         441.18
# QT_INSCRICAO                                                            2.0
#
#                                                                          5   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência autodeclarados pret...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                            NaN
# QT_INSCRICAO                                                            NaN
#
#                                                                          6   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com renda familiar bruta per capita...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     6
# NU_NOTACORTE                                                         568.18
# QT_INSCRICAO                                                           47.0
#
#                                                                          7   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos que, independentemente da renda (ar...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     6
# NU_NOTACORTE                                                         591.35
# QT_INSCRICAO                                                           20.0
#
#                                                                          8   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência que tenham renda fa...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                         471.17
# QT_INSCRICAO                                                            1.0
#
#                                                                          9   \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência que, independenteme...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                            NaN
# QT_INSCRICAO                                                            2.0
#
#                                                                          10  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       B
# DS_MOD_CONCORRENCIA       Candidatos/as que tiverem cursado e concluído ...
# NU_PERCENTUAL_BONUS                                                      10
# QT_VAGAS_CONCORRENCIA                                                     0
# NU_NOTACORTE                                                         625.85
# QT_INSCRICAO                                                          160.0
#
#                                                                          11  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                         118098
# NO_CURSO                                                            QUÍMICA
# DS_GRAU                                                        Licenciatura
# DS_TURNO                                                            Noturno
# TP_MOD_CONCORRENCIA                                                       B
# DS_MOD_CONCORRENCIA       Candidatos/as que tiverem cursado e concluído ...
# NU_PERCENTUAL_BONUS                                                       5
# QT_VAGAS_CONCORRENCIA                                                     0
# NU_NOTACORTE                                                         625.85
# QT_INSCRICAO                                                            6.0
#
#                                                           12  \
# NU_ANO                                                  2023
# NU_EDICAO                                                  1
# CO_IES                                                   580
# NO_IES                    UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                  UFPE
# DS_ORGANIZACAO_ACADEMICA                        Universidade
# DS_CATEGORIA_ADM                             Pública Federal
# NO_CAMPUS                          Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                  Caruaru
# SG_UF_CAMPUS                                              PE
# DS_REGIAO_CAMPUS                                    Nordeste
# CO_IES_CURSO                                          118098
# NO_CURSO                                             QUÍMICA
# DS_GRAU                                         Licenciatura
# DS_TURNO                                             Noturno
# TP_MOD_CONCORRENCIA                                        A
# DS_MOD_CONCORRENCIA                       Ampla concorrência
# NU_PERCENTUAL_BONUS                                        0
# QT_VAGAS_CONCORRENCIA                                     40
# NU_NOTACORTE                                          625.85
# QT_INSCRICAO                                            28.0
#
#                                                                          13  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados indígenas, com renda...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                         723.32
# QT_INSCRICAO                                                           16.0
#
#                                                                          14  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados indígenas que, indep...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                         718.92
# QT_INSCRICAO                                                           11.0
#
#                                                                          15  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados pretos ou pardos, co...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                    11
# NU_NOTACORTE                                                         748.67
# QT_INSCRICAO                                                          416.0
#
#                                                                          16  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos autodeclarados pretos ou pardos que...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                    11
# NU_NOTACORTE                                                          753.3
# QT_INSCRICAO                                                          268.0
#
#                                                                          17  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência autodeclarados pret...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                         698.96
# QT_INSCRICAO                                                           16.0
#
#                                                                          18  \
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com deficiência autodeclarados pret...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     1
# NU_NOTACORTE                                                          716.4
# QT_INSCRICAO                                                           13.0
#
#                                                                          19
# NU_ANO                                                                 2023
# NU_EDICAO                                                                 1
# CO_IES                                                                  580
# NO_IES                                   UNIVERSIDADE FEDERAL DE PERNAMBUCO
# SG_IES                                                                 UFPE
# DS_ORGANIZACAO_ACADEMICA                                       Universidade
# DS_CATEGORIA_ADM                                            Pública Federal
# NO_CAMPUS                                         Campus do Agreste Caruaru
# NO_MUNICIPIO_CAMPUS                                                 Caruaru
# SG_UF_CAMPUS                                                             PE
# DS_REGIAO_CAMPUS                                                   Nordeste
# CO_IES_CURSO                                                        1189778
# NO_CURSO                                                           MEDICINA
# DS_GRAU                                                         Bacharelado
# DS_TURNO                                                           Integral
# TP_MOD_CONCORRENCIA                                                       L
# DS_MOD_CONCORRENCIA       Candidatos com renda familiar bruta per capita...
# NU_PERCENTUAL_BONUS                                                       0
# QT_VAGAS_CONCORRENCIA                                                     6
# NU_NOTACORTE                                                         773.35
# QT_INSCRICAO                                                          320.0

# %%
sisu_df.groupby('SG_UF_CAMPUS')['NU_NOTACORTE'].mean()
# Out:
# SG_UF_CAMPUS
# AC    580.423849
# AL    572.758514
# AM    647.403168
# AP    604.225157
# BA    580.974403
# CE    630.544656
# DF    597.118632
# ES    611.016768
# GO    603.420756
# MA    579.885076
# MG    608.992912
# MS    592.546450
# MT    562.869886
# PA    637.188266
# PB    577.253595
# PE    606.472041
# PI    582.253218
# PR    603.089317
# RJ    627.999682
# RN    584.475392
# RR    556.332986
# RS    588.978623
# SC    608.507956
# SE    609.629486
# SP    626.152911
# Name: NU_NOTACORTE, dtype: float64

# %%
sisu_df.groupby('SG_UF_CAMPUS')['NU_NOTACORTE'].median()
# Out:
# SG_UF_CAMPUS
# AC    569.130
# AL    565.640
# AM    632.270
# AP    581.160
# BA    582.465
# CE    631.350
# DF    620.885
# ES    616.110
# GO    605.495
# MA    578.480
# MG    609.770
# MS    591.780
# MT    558.210
# PA    644.280
# PB    572.260
# PE    607.135
# PI    580.860
# PR    606.480
# RJ    629.975
# RN    582.770
# RR    550.060
# RS    591.280
# SC    610.900
# SE    607.200
# SP    629.780
# Name: NU_NOTACORTE, dtype: float64
